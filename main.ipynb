# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('water_dataX.csv')

# %%
data.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (�mhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
# 2                              0.1                       3243
# 3                              0.5                       5382
# 4                              0.4                       3428
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014
# 2                           5330  2014
# 3                           8443  2014
# 4                           5500  2014

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (�mhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
#  11  year                              1991 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 186.8+ KB

# %%
data.describe()
# Out:
#               year
# count  1991.000000
# mean   2010.038172
# std       3.057333
# min    2003.000000
# 25%    2008.000000
# 50%    2011.000000
# 75%    2013.000000
# max    2014.000000

# %%
#conversions
#converting all non nuerical values to NaN
data['Temp']=pd.to_numeric(data['Temp'],errors='coerce')
data['D.O. (mg/l)']=pd.to_numeric(data['D.O. (mg/l)'],errors='coerce')
data['PH']=pd.to_numeric(data['PH'],errors='coerce')
data['B.O.D. (mg/l)']=pd.to_numeric(data['B.O.D. (mg/l)'],errors='coerce')
data['NITRATENAN N+ NITRITENANN (mg/l)']=pd.to_numeric(data['NITRATENAN N+ NITRITENANN (mg/l)'],errors='coerce')
data['TOTAL COLIFORM (MPN/100ml)Mean']=pd.to_numeric(data['TOTAL COLIFORM (MPN/100ml)Mean'],errors='coerce')
data.dtypes
# Out:
# STATION CODE                         object
# LOCATIONS                            object
# STATE                                object
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (�mhos/cm)              object
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)           object
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %%
data['CONDUCTIVITY (�mhos/cm)']=pd.to_numeric(data['CONDUCTIVITY (�mhos/cm)'],errors='coerce')

# %%
data.isna()
# Out:
#       STATION CODE  LOCATIONS  STATE   Temp  D.O. (mg/l)     PH  \
# 0            False      False  False  False        False  False
# 1            False      False  False  False        False  False
# 2            False      False  False  False        False  False
# 3            False      False  False  False        False  False
# 4            False      False  False  False        False  False
# ...            ...        ...    ...    ...          ...    ...
# 1986         False      False  False   True        False  False
# 1987         False      False  False  False        False  False
# 1988         False      False  False  False        False  False
# 1989         False      False  False  False        False  False
# 1990         False      False  False  False        False  False
#
#       CONDUCTIVITY (�mhos/cm)  B.O.D. (mg/l)  \
# 0                       False           True
# 1                       False          False
# 2                       False          False
# 3                       False          False
# 4                       False          False
# ...                       ...            ...
# 1986                    False          False
# 1987                    False          False
# 1988                    False          False
# 1989                    False          False
# 1990                    False          False
#
#       NITRATENAN N+ NITRITENANN (mg/l)  FECAL COLIFORM (MPN/100ml)  \
# 0                                False                       False
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
# ...                                ...                         ...
# 1986                             False                       False
# 1987                             False                       False
# 1988                              True                       False
# 1989                              True                       False
# 1990                              True                       False
#
#       TOTAL COLIFORM (MPN/100ml)Mean   year
# 0                              False  False
# 1                              False  False
# 2                              False  False
# 3                              False  False
# 4                              False  False
# ...                              ...    ...
# 1986                           False  False
# 1987                           False  False
# 1988                           False  False
# 1989                           False  False
# 1990                           False  False
#
# [1991 rows x 12 columns]

# %%
data = data.dropna()

# %%
data.isna()
# Out:
#       STATION CODE  LOCATIONS  STATE   Temp  D.O. (mg/l)     PH  \
# 1            False      False  False  False        False  False
# 2            False      False  False  False        False  False
# 3            False      False  False  False        False  False
# 4            False      False  False  False        False  False
# 5            False      False  False  False        False  False
# ...            ...        ...    ...    ...          ...    ...
# 1981         False      False  False  False        False  False
# 1982         False      False  False  False        False  False
# 1984         False      False  False  False        False  False
# 1985         False      False  False  False        False  False
# 1987         False      False  False  False        False  False
#
#       CONDUCTIVITY (�mhos/cm)  B.O.D. (mg/l)  \
# 1                       False          False
# 2                       False          False
# 3                       False          False
# 4                       False          False
# 5                       False          False
# ...                       ...            ...
# 1981                    False          False
# 1982                    False          False
# 1984                    False          False
# 1985                    False          False
# 1987                    False          False
#
#       NITRATENAN N+ NITRITENANN (mg/l)  FECAL COLIFORM (MPN/100ml)  \
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
# 5                                False                       False
# ...                                ...                         ...
# 1981                             False                       False
# 1982                             False                       False
# 1984                             False                       False
# 1985                             False                       False
# 1987                             False                       False
#
#       TOTAL COLIFORM (MPN/100ml)Mean   year
# 1                              False  False
# 2                              False  False
# 3                              False  False
# 4                              False  False
# 5                              False  False
# ...                              ...    ...
# 1981                           False  False
# 1982                           False  False
# 1984                           False  False
# 1985                           False  False
# 1987                           False  False
#
# [1599 rows x 12 columns]

# %%
data.head()
# Out:
#   STATION CODE                                          LOCATIONS STATE  Temp  \
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...   GOA  29.8
# 2         1475                                ZUARI AT PANCHAWADI   GOA  29.5
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE   GOA  29.7
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY   GOA  29.5
# 5         1400             MANDOVI AT NEGHBOURHOOD OF PANAJI, GOA   GOA  30.0
#
#    D.O. (mg/l)   PH  CONDUCTIVITY (�mhos/cm)  B.O.D. (mg/l)  \
# 1          5.7  7.2                    189.0            2.0
# 2          6.3  6.9                    179.0            1.7
# 3          5.8  6.9                     64.0            3.8
# 4          5.8  7.3                     83.0            1.9
# 5          5.5  7.4                     81.0            1.5
#
#    NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 1                               0.2                       4953
# 2                               0.1                       3243
# 3                               0.5                       5382
# 4                               0.4                       3428
# 5                               0.1                       2853
#
#    TOTAL COLIFORM (MPN/100ml)Mean  year
# 1                          8391.0  2014
# 2                          5330.0  2014
# 3                          8443.0  2014
# 4                          5500.0  2014
# 5                          4049.0  2014

# %%
data.tail()
# Out:
#      STATION CODE                                          LOCATIONS STATE  \
# 1981         1160  TAMBIRAPARANI AT CHERANMADEVI,CAUSE WAY,TAMILNADU   NAN
# 1982         1161  TAMBIRAPARANI AT TIRUNELVELI,COLLECTORATE,    ...   NAN
# 1984         1328             TAMBIRAPARANI AT PAPPANKULAM,TAMILNADU   NAN
# 1985         1329  TAMBIRAPARANI AT RAIL BDG. NR. AMBASAMUDAM, TA...   NAN
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NAN
#
#       Temp  D.O. (mg/l)     PH  CONDUCTIVITY (�mhos/cm)  B.O.D. (mg/l)  \
# 1981  31.0          7.3  178.0                      6.7            1.5
# 1982  29.0          7.1  214.0                      6.8            2.3
# 1984  28.0          6.9  146.0                      7.1            2.0
# 1985  28.0          7.0  136.0                      7.5            1.4
# 1987  29.0          7.5  585.0                      6.3            2.6
#
#       NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 1981                             0.138                      0.138
# 1982                             0.585                      0.585
# 1984                             0.506                      0.506
# 1985                             0.609                      0.609
# 1987                             0.155                      0.155
#
#       TOTAL COLIFORM (MPN/100ml)Mean  year
# 1981                           190.0  2003
# 1982                           350.0  2003
# 1984                            38.0  2003
# 1985                           205.0  2003
# 1987                           315.0  2003

# %%
start=2
end=1779
station=data.iloc [start:end ,0]
location=data.iloc [start:end ,1]
state=data.iloc [start:end ,2]
do= data.iloc [start:end ,4].astype(np.float64)
value=0
ph = data.iloc[ start:end,5]  
co = data.iloc [start:end ,6].astype(np.float64)   
  
year=data.iloc[start:end,11]
tc=data.iloc [2:end ,10].astype(np.float64)


bod = data.iloc [start:end ,7].astype(np.float64)
na= data.iloc [start:end ,8].astype(np.float64)
na.dtype
# Out:
# dtype('float64')

# %%
data.info()
data=pd.concat([station,location,state,do,ph,co,bod,na,tc,year],axis=1)
data. columns = ['station','location','state','do','ph','co','bod','na','tc','year']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 1 to 1987
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1599 non-null   object
#  1   LOCATIONS                         1599 non-null   object
#  2   STATE                             1599 non-null   object
#  3   Temp                              1599 non-null   float64
#  4   D.O. (mg/l)                       1599 non-null   float64
#  5   PH                                1599 non-null   float64
#  6   CONDUCTIVITY (�mhos/cm)           1599 non-null   float64
#  7   B.O.D. (mg/l)                     1599 non-null   float64
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1599 non-null   float64
#  9   FECAL COLIFORM (MPN/100ml)        1599 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1599 non-null   float64
#  11  year                              1599 non-null   int64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 162.4+ KB

# %%
data.head()
# Out:
#   station                                location state   do   ph     co  bod  \
# 3    3181             RIVER ZUARI AT BORIM BRIDGE   GOA  5.8  6.9   64.0  3.8
# 4    3182            RIVER ZUARI AT MARCAIM JETTY   GOA  5.8  7.3   83.0  1.9
# 5    1400  MANDOVI AT NEGHBOURHOOD OF PANAJI, GOA   GOA  5.5  7.4   81.0  1.5
# 6    1476          MANDOVI AT TONCA, MARCELA, GOA   GOA  6.1  6.7  308.0  1.4
# 7    3185           RIVER MANDOVI AT AMONA BRIDGE   GOA  6.4  6.7  414.0  1.0
#
#     na      tc  year
# 3  0.5  8443.0  2014
# 4  0.4  5500.0  2014
# 5  0.1  4049.0  2014
# 6  0.3  5672.0  2014
# 7  0.2  9423.0  2014

# %%
#calulation of Ph
data['npH']=data.ph.apply(lambda x: (100 if (8.5>=x>=7)  
                                 else(80 if  (8.6>=x>=8.5) or (6.9>=x>=6.8) 
                                      else(60 if (8.8>=x>=8.6) or (6.8>=x>=6.7) 
                                          else(40 if (9>=x>=8.8) or (6.7>=x>=6.5)
                                              else 0)))))

# %%
#calculation of dissolved oxygen
data['ndo']=data.do.apply(lambda x:(100 if (x>=6)  
                                 else(80 if  (6>=x>=5.1) 
                                      else(60 if (5>=x>=4.1)
                                          else(40 if (4>=x>=3) 
                                              else 0)))))

# %%
#calculation of total coliform
data['nco']=data.tc.apply(lambda x:(100 if (5>=x>=0)  
                                 else(80 if  (50>=x>=5) 
                                      else(60 if (500>=x>=50)
                                          else(40 if (10000>=x>=500) 
                                              else 0)))))

# %%
#calc of B.D.O
data['nbdo']=data.bod.apply(lambda x:(100 if (3>=x>=0)  
                                 else(80 if  (6>=x>=3) 
                                      else(60 if (80>=x>=6)
                                          else(40 if (125>=x>=80) 
                                              else 0)))))

# %%
#calculation of electrical conductivity
data['nec']=data.co.apply(lambda x:(100 if (75>=x>=0)  
                                 else(80 if  (150>=x>=75) 
                                      else(60 if (225>=x>=150)
                                          else(40 if (300>=x>=225) 
                                              else 0)))))

# %%
#Calulation of nitrate
data['nna']=data.na.apply(lambda x:(100 if (20>=x>=0)  
                                 else(80 if  (50>=x>=20) 
                                      else(60 if (100>=x>=50)
                                          else(40 if (200>=x>=100) 
                                              else 0)))))

data.head()
# Out:
#   station                                location state   do   ph     co  bod  \
# 3    3181             RIVER ZUARI AT BORIM BRIDGE   GOA  5.8  6.9   64.0  3.8
# 4    3182            RIVER ZUARI AT MARCAIM JETTY   GOA  5.8  7.3   83.0  1.9
# 5    1400  MANDOVI AT NEGHBOURHOOD OF PANAJI, GOA   GOA  5.5  7.4   81.0  1.5
# 6    1476          MANDOVI AT TONCA, MARCELA, GOA   GOA  6.1  6.7  308.0  1.4
# 7    3185           RIVER MANDOVI AT AMONA BRIDGE   GOA  6.4  6.7  414.0  1.0
#
#     na      tc  year  npH  ndo  nco  nbdo  nec  nna
# 3  0.5  8443.0  2014   80   80   40    80  100  100
# 4  0.4  5500.0  2014  100   80   40   100   80  100
# 5  0.1  4049.0  2014  100   80   40   100   80  100
# 6  0.3  5672.0  2014   60  100   40   100    0  100
# 7  0.2  9423.0  2014   60  100   40   100    0  100

# %%
data['wph']=data.npH * 0.165
data['wdo']=data.ndo * 0.281
data['wbdo']=data.nbdo * 0.234
data['wec']=data.nec* 0.009
data['wna']=data.nna * 0.028
data['wco']=data.nco * 0.281
data['wqi']=data.wph+data.wdo+data.wbdo+data.wec+data.wna+data.wco 
data
# Out:
#      station                                           location state   do  \
# 3       3181                        RIVER ZUARI AT BORIM BRIDGE   GOA  5.8
# 4       3182                       RIVER ZUARI AT MARCAIM JETTY   GOA  5.8
# 5       1400             MANDOVI AT NEGHBOURHOOD OF PANAJI, GOA   GOA  5.5
# 6       1476                     MANDOVI AT TONCA, MARCELA, GOA   GOA  6.1
# 7       3185                      RIVER MANDOVI AT AMONA BRIDGE   GOA  6.4
# ...      ...                                                ...   ...  ...
# 1981    1160  TAMBIRAPARANI AT CHERANMADEVI,CAUSE WAY,TAMILNADU   NAN  7.3
# 1982    1161  TAMBIRAPARANI AT TIRUNELVELI,COLLECTORATE,    ...   NAN  7.1
# 1984    1328             TAMBIRAPARANI AT PAPPANKULAM,TAMILNADU   NAN  6.9
# 1985    1329  TAMBIRAPARANI AT RAIL BDG. NR. AMBASAMUDAM, TA...   NAN  7.0
# 1987    1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NAN  7.5
#
#          ph     co  bod     na      tc  year  ...  nbdo  nec  nna   wph  \
# 3       6.9   64.0  3.8  0.500  8443.0  2014  ...    80  100  100  13.2
# 4       7.3   83.0  1.9  0.400  5500.0  2014  ...   100   80  100  16.5
# 5       7.4   81.0  1.5  0.100  4049.0  2014  ...   100   80  100  16.5
# 6       6.7  308.0  1.4  0.300  5672.0  2014  ...   100    0  100   9.9
# 7       6.7  414.0  1.0  0.200  9423.0  2014  ...   100    0  100   9.9
# ...     ...    ...  ...    ...     ...   ...  ...   ...  ...  ...   ...
# 1981  178.0    6.7  1.5  0.138   190.0  2003  ...   100  100  100   0.0
# 1982  214.0    6.8  2.3  0.585   350.0  2003  ...   100  100  100   0.0
# 1984  146.0    7.1  2.0  0.506    38.0  2003  ...   100  100  100   0.0
# 1985  136.0    7.5  1.4  0.609   205.0  2003  ...   100  100  100   0.0
# 1987  585.0    6.3  2.6  0.155   315.0  2003  ...   100  100  100   0.0
#
#         wdo   wbdo   wec  wna    wco    wqi
# 3     22.48  18.72  0.90  2.8  11.24  69.34
# 4     22.48  23.40  0.72  2.8  11.24  77.14
# 5     22.48  23.40  0.72  2.8  11.24  77.14
# 6     28.10  23.40  0.00  2.8  11.24  75.44
# 7     28.10  23.40  0.00  2.8  11.24  75.44
# ...     ...    ...   ...  ...    ...    ...
# 1981  28.10  23.40  0.90  2.8  16.86  72.06
# 1982  28.10  23.40  0.90  2.8  16.86  72.06
# 1984  28.10  23.40  0.90  2.8  22.48  77.68
# 1985  28.10  23.40  0.90  2.8  16.86  72.06
# 1987  28.10  23.40  0.90  2.8  16.86  72.06
#
# [1597 rows x 23 columns]

# %%
new_data = pd.read_csv("cleaned_data.csv")
# Out:
# /Users/rishit/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
new_data.head()
# Out:
#    Unnamed: 0 station                                       location  \
# 0       136.0    1448        NAGAVALLI AT THOTAPALLI REGULATOR, A.P.
# 1       137.0    2352  RIVER VAMSHADHARA, KALINGAPATNAM,VIZIANAGARAM
# 2       138.0    3080  U/S OF KARAKAVAGU AT PALONCHA,  KHAMMAM, A.P.
# 3       139.0    3081  D/S OF KARAKAVAGU AT PALONCHA,  KHAMMAM, A.P.
# 4       394.0    1448        NAGAVALLI AT THOTAPALLI REGULATOR, A.P.
#
#             STATE   do   ph     co  bod   na      tc  ...   nbdo  nec    nna  \
# 0  ANDHRA PRADESH  5.5  7.6  569.0  1.3  0.9   141.0  ...  100.0  0.0  100.0
# 1  ANDHRA PRADESH  5.4  7.8  310.0  0.8  2.4   107.0  ...  100.0  0.0  100.0
# 2  ANDHRA PRADESH  7.1  7.8  516.0  0.7  0.5  1238.0  ...  100.0  0.0  100.0
# 3  ANDHRA PRADESH  6.9  8.0  505.0  0.9  0.7  1563.0  ...  100.0  0.0  100.0
# 4  ANDHRA PRADESH  6.0  7.3  432.0  1.2  3.0    78.0  ...  100.0  0.0  100.0
#
#     wph    wdo  wbdo  wec  wna    wco    wqi
# 0  16.5  22.48  23.4  0.0  2.8  16.86  82.04
# 1  16.5  22.48  23.4  0.0  2.8  16.86  82.04
# 2  16.5  28.10  23.4  0.0  2.8  11.24  82.04
# 3  16.5  28.10  23.4  0.0  2.8  11.24  82.04
# 4  16.5  28.10  23.4  0.0  2.8  16.86  87.66
#
# [5 rows x 24 columns]

# %%
#Taking the avg of the yearly water quality index and grouping it yearly
yearly = data.groupby('year')['wqi'].mean()

# %%
yearly
# Out:
# year
# 2003    66.759200
# 2004    55.200000
# 2005    73.894815
# 2006    74.589524
# 2007    74.629070
# 2008    72.926119
# 2009    74.354570
# 2010    76.534323
# 2011    77.763256
# 2012    78.478992
# 2013    77.942762
# 2014    78.557253
# Name: wqi, dtype: float64

# %%
yearly_wqi = yearly.reset_index(level=0,inplace=False)
yearly_wqi
# Out:
#     year        wqi
# 0   2003  66.759200
# 1   2004  55.200000
# 2   2005  73.894815
# 3   2006  74.589524
# 4   2007  74.629070
# 5   2008  72.926119
# 6   2009  74.354570
# 7   2010  76.534323
# 8   2011  77.763256
# 9   2012  78.478992
# 10  2013  77.942762
# 11  2014  78.557253

# %%
#Data Visualisation Here
import matplotlib.pyplot as plt
yearly_wqi=yearly_wqi.set_index('year')
yearly_wqi.plot(figsize=(15,6))
plt.show()

# %%
'''
The above graph shows how the wqi changed
'''
# Out:
# '\nThe above graph shows how the wqi changed\n'

# %%
###Plotting the Auto Correlation graph

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

# def parser(x):
#     return datetime.strptime('190'+x, '%Y-%m')

# series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
autocorrelation_plot(yearly_wqi)
pyplot.show()
# Out:
# <ipython-input-31-971f09da58e3>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
series = yearly_wqi

# %%
###Training a Rolling forecast ARIMA Model and Evaluating the results

# %%
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# # load dataset
# def parser(x):
# 	return datetime.strptime('190'+x, '%Y-%m')
# series = read_csv('shampoo-sales.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)
# series.index = series.index.to_period('M')
# split into train and test sets
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# Out:
# <ipython-input-36-7678e96003bd>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
# walk-forward validation
for t in range(len(test)):
    model = ARIMA(X, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# /Users/rishit/miniconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# predicted=79.121562, expected=76.534323
# predicted=79.121562, expected=77.763256
# predicted=79.121562, expected=78.478992
# predicted=79.121562, expected=77.942762
# predicted=79.121562, expected=78.557253

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test RMSE: 1.460

# %%
###Training an ARIMA Model and Residual error plot

# %%
# fit an ARIMA model and plot residual errors
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot
# load dataset
# def parser(x):
# 	return datetime.strptime('190'+x, '%Y-%m')
# series = read_csv('shampoo-sales.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)
# series.index = series.index.to_period('M')
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# <ipython-input-44-0fe58eca8325>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# /Users/rishit/miniconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /Users/rishit/miniconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /Users/rishit/miniconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /Users/rishit/miniconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    wqi   No. Observations:                   12
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                 -34.934
# Date:                Sat, 20 Nov 2021   AIC                             81.867
# Time:                        07:41:14   BIC                             84.255
# Sample:                             0   HQIC                            80.362
#                                  - 12
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5060      1.938     -0.261      0.794      -4.304       3.292
# ar.L2         -0.1008      2.597     -0.039      0.969      -5.190       4.988
# ar.L3         -0.1617      2.435     -0.066      0.947      -4.934       4.610
# ar.L4          0.2417      4.266      0.057      0.955      -8.120       8.603
# ar.L5          0.2936      0.600      0.489      0.625      -0.882       1.469
# sigma2        30.7912     37.175      0.828      0.408     -42.071     103.653
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.29   Jarque-Bera (JB):                 0.08
# Prob(Q):                              0.59   Prob(JB):                         0.96
# Heteroskedasticity (H):               0.03   Skew:                             0.12
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count  12.000000
# mean    6.913529
# std    19.794857
# min   -11.557754
# 25%    -0.359578
# 50%     1.370601
# 75%     4.943917
# max    66.759200
